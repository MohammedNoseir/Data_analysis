# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen

# %%
url='https://wuzzuf.net/search/jobs/?a=navbg%7Cspbg&q=illustrator'

# %%
client = urlopen(url)

# %%
html=client.read()

# %%
html
# Out:
# b'<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">272 illustrator Jobs in Egypt \xe2\x80\x93 Discover Job Details Now!</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Explore 272 illustrator Jobs in Egypt. Discover exciting opportunities with a leading recruitment company. Start your job search today!"/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexa
# ...

# %%
client.close()

# %%
soup= bs(html,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">272 illustrator Jobs in Egypt – Discover Job Details Now!</title>
# ...

# %%
cont=soup.find_all('div',{'class':'css-1gatmva e1v1l3u10'})

# %%
len(cont)
# Out:
# 15

# %%
bs.prettify(cont[0])
# Out:
# '<div class="css-1gatmva e1v1l3u10">\n <style data-emotion="css pkv5jc">\n  .css-pkv5jc{position:relative;min-height:60px;}\n </style>\n <div class="css-pkv5jc">\n  <a href="https://wuzzuf.net/jobs/careers/elmoasserbooks-Egypt-37460" rel="noreferrer" target="_blank">\n   <style data-emotion="css 17095x3">\n    .css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}\n   </style>\n  </a>\n  <style data-emotion="css laomuu">\n   .css-laomuu{padding-right:60px;}\n  </style>\n  <div class="css-laomuu">\n   <style data-emotion="css m604qf">\n    .css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}\n   </style>\n   <h2 class="css-m604qf">\n    <style data-emotion="css o171kl">\n     .css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}\n    </style>\n    <a class="css-o171kl" href="https://wuzzuf.net/jobs/p/SMZn4CMiXkOT-Illustrator-GP
# ...

# %%
cont[0].div.h2.text
# Out:
# 'Illustrator'

# %%
jtitle= cont[0].div.h2.text
jtitle
# Out:
# 'Illustrator'

# %%
jtitle=cont[0].findAll('h2',{'class':'css-m604qf'})
jtitle[0].text
# Out:
# 'Illustrator'

# %%
com_name=cont[0].findAll('a',{'css-17s97q8'})
com_name[0].text
# Out:
# 'GPS -'

# %%
typ=cont[0].findAll('div',{'css-1lh32fc'})
typ[0].text
# Out:
# 'Full TimeOn-site'

# %%
f=open("D:/FCDS/Data Sets/Self Study/6 Data Scrabing/noo.text",'w')
header='j_title,company_name,job_type\n'
f.write(header)
# Out:
# 30

# %%
for conten in cont:
  jtitle=conten.findAll('h2',{'class':'css-m604qf'})
  j_title=jtitle[0].text.strip() 
  com_name=conten.findAll('a',{'class':'css-17s97q8'})
  company_name=com_name[0].text.strip() 
  typ=conten.findAll('div',{'class':'css-1lh32fc'})
  jop_type=typ[0].text.strip() 
  #print(j_title)
  #print(com_name)
  #print(jop_type)
  #print()
  #print(jop_type+','+company_namee+','+j_title+"\n")
  f.write(f"{jop_type},{company_name},{j_title}\n")
f.close()

# %%
df = pd.read_csv(r"D:/FCDS/Data Sets/Self Study/6 Data Scrabing/noo.text")

df
# Out:
#                       j_title             company_name  \
# 0            Full TimeOn-site                    GPS -
# 1             Full TimeRemote         Adverse Agency -
# 2            Full TimeOn-site         Horizon Agency -
# 3   Freelance / ProjectRemote           Confidential -
# 4            Full TimeOn-site            Helal Group -
# 5             Full TimeRemote       Edutech Labs Fze -
# 6            Full TimeOn-site           Confidential -
# 7            Full TimeOn-site  Palmier Developments  -
# 8            Full TimeOn-site        NewTech Company -
# 9             Full TimeHybrid       Localized Vision -
# 10           Full TimeOn-site   Continental Comfort  -
# 11           Full TimeOn-site         Alarabia Group -
# 12           Full TimeOn-site   The Translation Gate -
# 13           Full TimeOn-site               Floortec -
# 14           Full TimeOn-site           Confidential -
#
#                              job_type
# 0                         Illustrator
# ...
