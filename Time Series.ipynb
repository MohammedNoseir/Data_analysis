# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("D:/FCDS/Data Sets/data/multiTimeline.csv",skiprows=1)
df.head()
# Out:
#      Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0  2004-01                100                31                    48
# 1  2004-02                 75                26                    49
# 2  2004-03                 67                24                    47
# 3  2004-04                 70                22                    48
# 4  2004-05                 72                22                    43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 168 non-null    object
#  1   diet: (Worldwide)     168 non-null    int64
#  2   gym: (Worldwide)      168 non-null    int64
#  3   finance: (Worldwide)  168 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.4+ KB

# %%
df.columns=['Month','diet','gym','finance']
df
# Out:
#        Month  diet  gym  finance
# 0    2004-01   100   31       48
# 1    2004-02    75   26       49
# 2    2004-03    67   24       47
# 3    2004-04    70   22       48
# 4    2004-05    72   22       43
# ..       ...   ...  ...      ...
# 163  2017-08    46   52       43
# 164  2017-09    44   50       47
# 165  2017-10    44   47       45
# 166  2017-11    41   47       47
# 167  2017-12    39   45       56
#
# [168 rows x 4 columns]

# %%
df['Month']=pd.to_datetime(df['Month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    168 non-null    datetime64[ns]
#  1   diet     168 non-null    int64
#  2   gym      168 non-null    int64
#  3   finance  168 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 5.4 KB

# %%
df.set_index('Month',inplace=True)
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2004-01-01 to 2017-12-01
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   diet     168 non-null    int64
#  1   gym      168 non-null    int64
#  2   finance  168 non-null    int64
# dtypes: int64(3)
# memory usage: 5.2 KB

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
df[['diet']].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
df[['diet']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
df[['gym']].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
df[['gym']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
pd.concat([df[['diet']].rolling(12).mean(), df[['gym']].rolling(12).mean()],axis=1)
# Out:
#                  diet        gym
# Month
# 2004-01-01        NaN        NaN
# 2004-02-01        NaN        NaN
# 2004-03-01        NaN        NaN
# 2004-04-01        NaN        NaN
# 2004-05-01        NaN        NaN
# ...               ...        ...
# 2017-08-01  46.833333  49.250000
# 2017-09-01  46.916667  49.166667
# 2017-10-01  47.250000  49.333333
# 2017-11-01  47.416667  49.583333
# 2017-12-01  47.666667  49.666667
#
# [168 rows x 2 columns]

# %%
pd.concat([df[['diet']].rolling(12).mean(), df[['gym']].rolling(12).mean()],axis=1).plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>
